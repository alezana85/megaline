# %% [markdown]
# # Descripción del proyecto

# %% [markdown]
# Trabajas como analista para el operador de telecomunicaciones `Megaline`. La empresa ofrece a sus clientes dos tarifas de prepago, *Surf* y *Ultimate*. El departamento comercial quiere saber cuál de los planes genera más ingresos para poder ajustar el presupuesto de publicidad.
#
# Vas a realizar un análisis preliminar de las tarifas basado en una selección de clientes relativamente pequeña. Tendrás los datos de **500 clientes de Megaline**: quiénes son los clientes, de dónde son, qué tarifa usan, así como la cantidad de llamadas que hicieron y los mensajes de texto que enviaron en 2018. Tu trabajo es analizar el comportamiento de los clientes y determinar qué tarifa de prepago genera más ingresos. Más adelante, encontrarás en las instrucciones del proyecto cuáles son exactamente los aspectos del comportamiento de los clientes que debes analizar. Determinar qué plan, en promedio, aporta más ingresos es una cuestión que se abordará mediante pruebas estadísticas. Más adelante encontrarás más información al respecto en la sección de instrucciones del proyecto.

# %% [markdown]
# ## Descripción de las tarifas

# %% [markdown]
# Nota: Megaline redondea los segundos a minutos y los megabytes a gigabytes. Para llamadas, cada llamada individual se redondea: incluso si la llamada duró solo un segundo, se contará como un minuto. Para tráfico web, las sesiones web individuales no se redondean. En vez de esto, el total del mes se redondea hacia arriba. Si alguien usa 1025 megabytes este mes, se le cobrarán 2 gigabytes.
#
# A continuación puedes ver una descripción de las tarifas:
#
#  * **Surf**
#    1. Pago mensual: 20$.
#    2. 500 minutos al mes, 50 SMS y 15 GB de datos.
#    3. Si se exceden los límites del paquete:
#        - 1 minuto: 3 centavos.
#        - 1 SMS: 3 centavos.
#        - 1 GB de datos: 10$.
#
#  * **Ultimate**
#    1. Pago mensual: 70$.
#    2. 3000 minutos al mes, 1000 SMS y 30 GB de datos.
#    3. Si se exceden los límites del paquete:
#        - 1 minuto: 1 centavo.
#        - 1 SMS: 1 centavo.
#        - 1 GB de datos: 7$.

# %% [markdown]
# ## Diccionario de datos
#
# En este proyecto, trabajarás con cinco tablas diferentes.

# %% [markdown]
#  1. La tabla `users` (datos sobre los usuarios):
#
#     - *user_id:* identificador único del usuario.
#     - *first_name:* nombre del usuario.
#     - *last_name:* apellido del usuario.
#     - *age:* edad del usuario (en años).
#     - *reg_date:* fecha de suscripción (dd, mm, aa).
#     - *churn_date:* la fecha en la que el usuario dejó de usar el servicio (si el valor es ausente, la tarifa se estaba usando cuando fue extraída esta base de datos).
#     - *city:* ciudad de residencia del usuario.
#     - *plan:* nombre de la tarifa.
#
#  2. La tabla `calls` (datos sobre las llamadas):
#
#     - *id:* identificador único de la llamada.
#     - *call_date:* fecha de la llamada.
#     - *duration:* duración de la llamada (en minutos).
#     - *user_id:* el identificador del usuario que realiza la llamada.
#
#  3. La tabla `messages` (datos sobre los SMS):
#
#     - *id:* identificador único del SMS.
#     - *message_date:* fecha del SMS.
#     - *user_id:* el identificador del usuario que manda el SMS.
#
#  4. La tabla `internet` (datos sobre las sesiones web):
#
#     - *id:* identificador único de la sesión.
#     - *mb_used:* el volumen de datos gastados durante la sesión (en megabytes).
#     - *session_date:* fecha de la sesión web.
#     - *user_id:* identificador del usuario.
#
#  5. La tabla `plans` (datos sobre las tarifas):
#
#     - *plan_name:* nombre de la tarifa.
#     - *usd_monthly_fee:* pago mensual en dólares estadounidenses.
#     - *minutes_included:* minutos incluidos al mes.
#     - *messages_included:* SMS incluidos al mes.
#     - *mb_per_month_included:* datos incluidos al mes (en megabytes).
#     - *usd_per_minute:* precio por minuto tras exceder los límites del paquete (por ejemplo, si el paquete incluye 100 minutos, el operador cobrará el minuto 101).
#     - *usd_per_message:* precio por SMS tras exceder los límites del paquete.
#     - *usd_per_gb:* precio por gigabyte de los datos extra tras exceder los límites del paquete (1 GB = 1024 megabytes).

# %% [markdown]
# ## Instrucciones para completar el proyecto
#
# Se te facilita una plantilla del cuaderno. El cuaderno te orientará sobre qué código escribir y te pedirá que expliques tus resultados a lo largo del proceso. Para completar el proyecto, tienes que rellenar cada celda de código en la plantilla y editar las celdas Markdown donde la plantilla te pide que expliques tus resultados.
#
# Asegúrate también de incluir una introducción que describa brevemente cuáles son tus objetivos y una conclusión que resuma brevemente tus resultados.

# %% [markdown]
# ### **Paso 1.** Abre el archivo de datos y estudia la información general
#
# A continuación encontrarás las rutas de los archivos que hay que leer:
#
# `/datasets/megaline_calls.csv`
#
# `/datasets/megaline_internet.csv`
#
# `/datasets/megaline_messages.csv`
#
# `/datasets/megaline_plans.csv`
#
# `/datasets/megaline_users.csv`

# %% [markdown]
# ### **Paso 2.** Prepara los datos
#
#  - Convierte los datos en los tipos necesarios.
#  - Encuentra y elimina errores en los datos. Asegúrate de explicar qué errores encontraste y cómo los eliminaste.
#
# Para cada usuario, busca:
#
#  - El número de llamadas realizadas y minutos utilizados al mes.
#  - La cantidad de los SMS enviados por mes.
#  - El volumen de datos por mes.
#  - Los ingresos mensuales por cada usuario. Para ello, necesitas:
#     - Restar el límite del paquete gratuito del número total de llamadas, mensajes de texto y datos.
#     - Multiplicar el resultado por el valor de la tarifa de llamadas.
#     - Añadir la cuota mensual en función del plan de llamadas.

# %% [markdown]
# ### **Paso 3.** Analiza los datos
#
# Describe el comportamiento de la clientela:
#  - Encuentra los minutos, SMS y volumen de datos que requieren los usuarios de cada tarifa por mes.
#  - Calcula la media, la varianza y la desviación estándar.
#  - Traza histogramas. Describe las distribuciones.

# %% [markdown]
# ### **Paso 4.** Prueba las hipótesis
#
#  - El ingreso promedio de los usuarios de las tarifas Ultimate y Surf difiere.
#  - El ingreso promedio de los usuarios en el área de estados Nueva York-Nueva Jersey es diferente al de los usuarios de otras regiones.
#
# Tú decides qué valor alfa usar. Además, tienes que explicar:
#
#  - Cómo formulaste las hipótesis nula y alternativa.
#  - Qué criterio utilizaste para probar las hipótesis y por qué.

# %% [markdown]
# ### **Paso 5.** Escribe una conclusión general
#
# Formato: Completa todas las tareas en un **Jupyter Notebook**. Almacena todo el código en las celdas `code` y las explicaciones de texto en las celdas `markdown`. Añade títulos y el formato adecuado si es necesario.

# %% [markdown]
# # ¿Cuál es la mejor tarifa?
#
# Trabajas como analista para el operador de telecomunicaciones Megaline. La empresa ofrece a sus clientes dos tarifas de prepago, Surf y Ultimate. El departamento comercial quiere saber cuál de las tarifas genera más ingresos para poder ajustar el presupuesto de publicidad.
#
# Vas a realizar un análisis preliminar de las tarifas basado en una selección de clientes relativamente pequeña. Tendrás los datos de 500 clientes de Megaline: quiénes son los clientes, de dónde son, qué tarifa usan, así como la cantidad de llamadas que hicieron y los mensajes de texto que enviaron en 2018. Tu trabajo es analizar el comportamiento de los clientes y determinar qué tarifa de prepago genera más ingresos.

# %% [markdown]
# ## Inicialización

# %%
# Cargar todas las librerías
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
from scipy import stats as st
from matplotlib import pyplot as plt

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Cargar datos

# %%
# Carga los archivos de datos en diferentes DataFrames
users = pd.read_csv('datasets/megaline_users.csv')
plans = pd.read_csv('datasets/megaline_plans.csv')
calls = pd.read_csv('datasets/megaline_calls.csv')
messages = pd.read_csv('datasets/megaline_messages.csv')
internet = pd.read_csv('datasets/megaline_internet.csv')

# %% [markdown]
# ## Preparar los datos

# %%
def print_info(df, df_name):
    print('Información del DataFrame', df_name, ':' )
    df.info()
    print('\n')
    print('Descripción del DataFrame', df_name, ':')
    display(df.describe())
    print('\n')
    print('Primeras 5 filas del DataFrame', df_name, ':')
    display(df.head())
    print('\n')
    print('Hay', df.isnull().sum().sum(), 'valores nulos en el DataFrame', df_name)
    print('Hay', df.duplicated().sum(), 'valores duplicados en el DataFrame', df_name)

# %%
# Tabla users
print_info(users, 'users')
# Out:
# Información del DataFrame users :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
#
#
# Descripción del DataFrame users :
#            user_id         age
# count   500.000000  500.000000
# mean   1249.500000   45.486000
# std     144.481833   16.972269
# min    1000.000000   18.000000
# 25%    1124.750000   30.000000
# 50%    1249.500000   46.000000
# 75%    1374.250000   61.000000
# max    1499.000000   75.000000
# Primeras 5 filas del DataFrame users :
# ...

# %%
# Tabla plans
print_info(plans, 'plans')
# Out:
# Información del DataFrame plans :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 260.0+ bytes
#
#
# Descripción del DataFrame plans :
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# ...

# %%
# Tabla calls
print_info(calls, 'calls')
# Out:
# Información del DataFrame calls :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB
#
#
# Descripción del DataFrame calls :
#              user_id       duration
# count  137735.000000  137735.000000
# mean     1247.658046       6.745927
# std       139.416268       5.839241
# min      1000.000000       0.000000
# 25%      1128.000000       1.290000
# 50%      1247.000000       5.980000
# 75%      1365.000000      10.690000
# max      1499.000000      37.600000
# Primeras 5 filas del DataFrame calls :
#          id  user_id   call_date  duration
# 0   1000_93     1000  2018-12-27      8.52
# ...

# %%
# Tabla messages
print_info(messages, 'messages')
# Out:
# Información del DataFrame messages :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB
#
#
# Descripción del DataFrame messages :
#             user_id
# count  76051.000000
# mean    1245.972768
# std      139.843635
# min     1000.000000
# 25%     1123.000000
# 50%     1251.000000
# 75%     1362.000000
# max     1497.000000
# Primeras 5 filas del DataFrame messages :
#          id  user_id message_date
# 0  1000_125     1000   2018-12-27
# 1  1000_160     1000   2018-12-31
# 2  1000_223     1000   2018-12-31
# 3  1000_251     1000   2018-12-27
# 4  1000_255     1000   2018-12-26
# Hay 0 valores nulos en el DataFrame messages
# ...

# %%
# Tabla internet
print_info(internet, 'internet')
# Out:
# Información del DataFrame internet :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB
#
#
# Descripción del DataFrame internet :
#              user_id        mb_used
# count  104825.000000  104825.000000
# mean     1242.496361     366.713701
# std       142.053913     277.170542
# min      1000.000000       0.000000
# 25%      1122.000000     136.080000
# 50%      1236.000000     343.980000
# 75%      1367.000000     554.610000
# max      1499.000000    1693.470000
# Primeras 5 filas del DataFrame internet :
#          id  user_id session_date  mb_used
# ...

# %% [markdown]
# ## Tarifas

# %%
# Imprime la información general/resumida sobre el DataFrame de las tarifas
print('Información del DataFrame plans:')   
plans.info()
print('\n')
print('Descripción del DataFrame plans:')
display(plans.describe())
# Out:
# Información del DataFrame plans:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   usd_monthly_pay        2 non-null      int64
#  4   usd_per_gb             2 non-null      int64
#  5   usd_per_message        2 non-null      float64
#  6   usd_per_minute         2 non-null      float64
#  7   plan_name              2 non-null      object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 260.0+ bytes
#
#
# Descripción del DataFrame plans:
#        messages_included  mb_per_month_included  minutes_included  \
# count           2.000000               2.000000          2.000000
# mean          525.000000           23040.000000       1750.000000
# ...

# %%
# Imprime una muestra de los datos para las tarifas
plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# ### Corregir datos

# %%
# Transormar la columna mb_per_month_included de la tabla plans a gigabytes
plans['mb_per_month_included'] = plans['mb_per_month_included'] / 1024
plans
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                   15.0               500
# 1               1000                   30.0              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# ### Enriquecer los datos

# %%
plans.rename(columns={'mb_per_month_included': 'gb_per_month_included'}, inplace=True)
plans
# Out:
#    messages_included  gb_per_month_included  minutes_included  \
# 0                 50                   15.0               500
# 1               1000                   30.0              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# ## Usuarios/as

# %%
# Imprime la información general/resumida sobre el DataFrame de usuarios
print('Información del DataFrame users:')
users.info()
print('\n')
print('Descripción del DataFrame users:')
display(users.describe())
# Out:
# Información del DataFrame users:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   first_name  500 non-null    object
#  2   last_name   500 non-null    object
#  3   age         500 non-null    int64
#  4   city        500 non-null    object
#  5   reg_date    500 non-null    object
#  6   plan        500 non-null    object
#  7   churn_date  34 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
#
#
# Descripción del DataFrame users:
#            user_id         age
# count   500.000000  500.000000
# mean   1249.500000   45.486000
# std     144.481833   16.972269
# min    1000.000000   18.000000
# 25%    1124.750000   30.000000
# 50%    1249.500000   46.000000
# 75%    1374.250000   61.000000
# max    1499.000000   75.000000

# %%
# Imprime una muestra de datos para usuarios
users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   Anamaria       Bauer   45
# 1       1001     Mickey   Wilkerson   28
# 2       1002     Carlee     Hoffman   36
# 3       1003   Reynaldo     Jenkins   52
# 4       1004    Leonila    Thompson   40
# ..       ...        ...         ...  ...
# 495     1495      Fidel      Sharpe   67
# 496     1496      Ariel    Shepherd   49
# 497     1497      Donte     Barrera   49
# 498     1498       Scot  Williamson   51
# 499     1499      Shena     Dickson   37
#
#                                           city    reg_date      plan  \
# 0        Atlanta-Sandy Springs-Roswell, GA MSA  2018-12-24  ultimate
# 1              Seattle-Tacoma-Bellevue, WA MSA  2018-08-13      surf
# 2         Las Vegas-Henderson-Paradise, NV MSA  2018-10-21      surf
# 3                                Tulsa, OK MSA  2018-01-28      surf
# 4              Seattle-Tacoma-Bellevue, WA MSA  2018-05-23      surf
# ...

# %% [markdown]
# ### Corregir los datos

# %%
# Transformar las columnas reg_date y churn_date de la tabla users a formato datetime
users['reg_date'] = pd.to_datetime(users['reg_date'], format='%Y-%m-%d')
users['churn_date'] = pd.to_datetime(users['churn_date'], format='%Y-%m-%d')
# Llenar los valores nulos en la columna churn_date con la fecha de fin del año
users['churn_date'] = users['churn_date'].fillna(pd.to_datetime('2018-12-31', format='%Y-%m-%d'))
users
# Out:
#      user_id first_name   last_name  age  \
# 0       1000   Anamaria       Bauer   45
# 1       1001     Mickey   Wilkerson   28
# 2       1002     Carlee     Hoffman   36
# 3       1003   Reynaldo     Jenkins   52
# 4       1004    Leonila    Thompson   40
# ..       ...        ...         ...  ...
# 495     1495      Fidel      Sharpe   67
# 496     1496      Ariel    Shepherd   49
# 497     1497      Donte     Barrera   49
# 498     1498       Scot  Williamson   51
# 499     1499      Shena     Dickson   37
#
#                                           city   reg_date      plan churn_date
# 0        Atlanta-Sandy Springs-Roswell, GA MSA 2018-12-24  ultimate 2018-12-31
# 1              Seattle-Tacoma-Bellevue, WA MSA 2018-08-13      surf 2018-12-31
# 2         Las Vegas-Henderson-Paradise, NV MSA 2018-10-21      surf 2018-12-31
# 3                                Tulsa, OK MSA 2018-01-28      surf 2018-12-31
# ...

# %% [markdown]
# ### Enriquecer los datos

# %%
# Unir la columnas first_name y last_name en una sola columna
users['full_name'] = users['first_name'] + ' ' + users['last_name']
# Eliminar las columnas first_name y last_name
users = users.drop(['first_name', 'last_name'], axis=1)
# Ordenar las columnas
users = users[['user_id', 'full_name', 'age', 'city', 'reg_date', 'churn_date', 'plan']]
users
# Out:
#      user_id         full_name  age  \
# 0       1000    Anamaria Bauer   45
# 1       1001  Mickey Wilkerson   28
# 2       1002    Carlee Hoffman   36
# 3       1003  Reynaldo Jenkins   52
# 4       1004  Leonila Thompson   40
# ..       ...               ...  ...
# 495     1495      Fidel Sharpe   67
# 496     1496    Ariel Shepherd   49
# 497     1497     Donte Barrera   49
# 498     1498   Scot Williamson   51
# 499     1499     Shena Dickson   37
#
#                                           city   reg_date churn_date      plan
# 0        Atlanta-Sandy Springs-Roswell, GA MSA 2018-12-24 2018-12-31  ultimate
# 1              Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 2         Las Vegas-Henderson-Paradise, NV MSA 2018-10-21 2018-12-31      surf
# 3                                Tulsa, OK MSA 2018-01-28 2018-12-31      surf
# 4              Seattle-Tacoma-Bellevue, WA MSA 2018-05-23 2018-12-31      surf
# ...

# %% [markdown]
# ## Llamadas

# %%
# Imprime la información general/resumida sobre el DataFrame de las llamadas
print('Información del DataFrame calls:')
calls.info()
print('\n')
print('Descripción del DataFrame calls:')
display(calls.describe())
# Out:
# Información del DataFrame calls:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB
#
#
# Descripción del DataFrame calls:
#              user_id       duration
# count  137735.000000  137735.000000
# mean     1247.658046       6.745927
# std       139.416268       5.839241
# min      1000.000000       0.000000
# 25%      1128.000000       1.290000
# 50%      1247.000000       5.980000
# 75%      1365.000000      10.690000
# max      1499.000000      37.600000

# %%
# Imprime una muestra de datos para las llamadas
calls
# Out:
#               id  user_id   call_date  duration
# 0        1000_93     1000  2018-12-27      8.52
# 1       1000_145     1000  2018-12-27     13.66
# 2       1000_247     1000  2018-12-27     14.48
# 3       1000_309     1000  2018-12-28      5.76
# 4       1000_380     1000  2018-12-30      4.22
# ...          ...      ...         ...       ...
# 137730  1499_199     1499  2018-11-21      8.72
# 137731  1499_200     1499  2018-10-20     10.89
# 137732  1499_201     1499  2018-09-21      8.12
# 137733  1499_202     1499  2018-10-10      0.37
# 137734  1499_203     1499  2018-12-29     13.86
#
# [137735 rows x 4 columns]

# %% [markdown]
# ### Corregir los datos

# %%
# Convertir la columna call_date a datetime
calls['call_date'] = pd.to_datetime(calls['call_date'], format='%Y-%m-%d')
#Redondear la duración de las llamadas a minutos hacia arriba
calls['duration'] = np.ceil(calls['duration']).astype(int)
# Verificar si hay llamas con duración 0
calls[calls['duration'] == 0]
# Eliminar las llamadas con duración 0
calls = calls[calls['duration'] != 0]
calls
# Out:
#               id  user_id  call_date  duration
# 0        1000_93     1000 2018-12-27         9
# 1       1000_145     1000 2018-12-27        14
# 2       1000_247     1000 2018-12-27        15
# 3       1000_309     1000 2018-12-28         6
# 4       1000_380     1000 2018-12-30         5
# ...          ...      ...        ...       ...
# 137730  1499_199     1499 2018-11-21         9
# 137731  1499_200     1499 2018-10-20        11
# 137732  1499_201     1499 2018-09-21         9
# 137733  1499_202     1499 2018-10-10         1
# 137734  1499_203     1499 2018-12-29        14
#
# [110901 rows x 4 columns]

# %% [markdown]
# ### Enriquecer los datos

# %%
# Agregar una columna con el mes de la llamada
calls['month'] = calls['call_date'].dt.month
# Cambia el nombre de la columna duration
calls.rename(columns={'month': 'call_month' , 'duration': 'duration_min'}, inplace=True)
# Ordenar las columnas
calls = calls[['id', 'user_id', 'call_date', 'call_month', 'duration_min']]
calls
# Out:
#               id  user_id  call_date  call_month  duration_min
# 0        1000_93     1000 2018-12-27          12             9
# 1       1000_145     1000 2018-12-27          12            14
# 2       1000_247     1000 2018-12-27          12            15
# 3       1000_309     1000 2018-12-28          12             6
# 4       1000_380     1000 2018-12-30          12             5
# ...          ...      ...        ...         ...           ...
# 137730  1499_199     1499 2018-11-21          11             9
# 137731  1499_200     1499 2018-10-20          10            11
# 137732  1499_201     1499 2018-09-21           9             9
# 137733  1499_202     1499 2018-10-10          10             1
# 137734  1499_203     1499 2018-12-29          12            14
#
# [110901 rows x 5 columns]

# %% [markdown]
# ## Mensajes

# %%
# Imprime la información general/resumida sobre el DataFrame de los mensajes
print('Información del DataFrame messages:')
messages.info()
print('\n')
print('Descripción del DataFrame messages:')
display(messages.describe())
# Out:
# Información del DataFrame messages:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76051 entries, 0 to 76050
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            76051 non-null  object
#  1   user_id       76051 non-null  int64
#  2   message_date  76051 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB
#
#
# Descripción del DataFrame messages:
#             user_id
# count  76051.000000
# mean    1245.972768
# std      139.843635
# min     1000.000000
# 25%     1123.000000
# 50%     1251.000000
# 75%     1362.000000
# max     1497.000000

# %%
# Imprime una muestra de datos para los mensajes
messages
# Out:
#              id  user_id message_date
# 0      1000_125     1000   2018-12-27
# 1      1000_160     1000   2018-12-31
# 2      1000_223     1000   2018-12-31
# 3      1000_251     1000   2018-12-27
# 4      1000_255     1000   2018-12-26
# ...         ...      ...          ...
# 76046  1497_526     1497   2018-12-24
# 76047  1497_536     1497   2018-12-24
# 76048  1497_547     1497   2018-12-31
# 76049  1497_558     1497   2018-12-24
# 76050  1497_613     1497   2018-12-23
#
# [76051 rows x 3 columns]

# %% [markdown]
# ### Corregir los datos

# %%
# Convertir la columna message_date a datetime
messages['message_date'] = pd.to_datetime(messages['message_date'], format='%Y-%m-%d')
messages
# Out:
#              id  user_id message_date
# 0      1000_125     1000   2018-12-27
# 1      1000_160     1000   2018-12-31
# 2      1000_223     1000   2018-12-31
# 3      1000_251     1000   2018-12-27
# 4      1000_255     1000   2018-12-26
# ...         ...      ...          ...
# 76046  1497_526     1497   2018-12-24
# 76047  1497_536     1497   2018-12-24
# 76048  1497_547     1497   2018-12-31
# 76049  1497_558     1497   2018-12-24
# 76050  1497_613     1497   2018-12-23
#
# [76051 rows x 3 columns]

# %% [markdown]
# ### Enriquecer los datos

# %%
# Agregar columna para el mes de la fecha de los mensajes
messages['month'] = messages['message_date'].dt.month
# Cambiar el nombre de la columna
messages.rename(columns={'month': 'message_month'}, inplace=True)
messages
# Out:
#              id  user_id message_date  message_month
# 0      1000_125     1000   2018-12-27             12
# 1      1000_160     1000   2018-12-31             12
# 2      1000_223     1000   2018-12-31             12
# 3      1000_251     1000   2018-12-27             12
# 4      1000_255     1000   2018-12-26             12
# ...         ...      ...          ...            ...
# 76046  1497_526     1497   2018-12-24             12
# 76047  1497_536     1497   2018-12-24             12
# 76048  1497_547     1497   2018-12-31             12
# 76049  1497_558     1497   2018-12-24             12
# 76050  1497_613     1497   2018-12-23             12
#
# [76051 rows x 4 columns]

# %% [markdown]
# ## Internet

# %%
# Imprime la información general/resumida sobre el DataFrame de internet
print('Información del DataFrame internet:')
internet.info()
print('\n')
print('Descripción del DataFrame internet:')
display(internet.describe())
# Out:
# Información del DataFrame internet:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104825 entries, 0 to 104824
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            104825 non-null  object
#  1   user_id       104825 non-null  int64
#  2   session_date  104825 non-null  object
#  3   mb_used       104825 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.2+ MB
#
#
# Descripción del DataFrame internet:
#              user_id        mb_used
# count  104825.000000  104825.000000
# mean     1242.496361     366.713701
# std       142.053913     277.170542
# min      1000.000000       0.000000
# 25%      1122.000000     136.080000
# 50%      1236.000000     343.980000
# 75%      1367.000000     554.610000
# max      1499.000000    1693.470000

# %%
# Imprime una muestra de datos para el tráfico de internet
internet
# Out:
#               id  user_id session_date  mb_used
# 0        1000_13     1000   2018-12-29    89.86
# 1       1000_204     1000   2018-12-31     0.00
# 2       1000_379     1000   2018-12-28   660.40
# 3       1000_413     1000   2018-12-26   270.99
# 4       1000_442     1000   2018-12-27   880.22
# ...          ...      ...          ...      ...
# 104820  1499_215     1499   2018-10-20   218.06
# 104821  1499_216     1499   2018-12-30   304.72
# 104822  1499_217     1499   2018-09-22   292.75
# 104823  1499_218     1499   2018-12-07     0.00
# 104824  1499_219     1499   2018-12-24   758.31
#
# [104825 rows x 4 columns]

# %% [markdown]
# ### Corregir los datos

# %%
# Convertir la columna session_date a datetime
internet['session_date'] = pd.to_datetime(internet['session_date'], format='%Y-%m-%d')
# Redondear el tráfico de internet a gigabytes
internet['mb_used'] = np.ceil(internet['mb_used'] / 1024).astype(int)
internet
# Out:
#               id  user_id session_date  mb_used
# 0        1000_13     1000   2018-12-29        1
# 1       1000_204     1000   2018-12-31        0
# 2       1000_379     1000   2018-12-28        1
# 3       1000_413     1000   2018-12-26        1
# 4       1000_442     1000   2018-12-27        1
# ...          ...      ...          ...      ...
# 104820  1499_215     1499   2018-10-20        1
# 104821  1499_216     1499   2018-12-30        1
# 104822  1499_217     1499   2018-09-22        1
# 104823  1499_218     1499   2018-12-07        0
# 104824  1499_219     1499   2018-12-24        1
#
# [104825 rows x 4 columns]

# %% [markdown]
# ### Enriquecer los datos

# %%
# Agregar columna para el mes de la fecha de las sesiones de internet
internet['month'] = internet['session_date'].dt.month
# Cambiar el nombre de la columna
internet.rename(columns={'month': 'session_month', 'mb_used': 'gb_used'}, inplace=True)
# Ordenar las columnas
internet = internet[['id', 'user_id', 'session_date', 'session_month', 'gb_used']]
internet
# Out:
#               id  user_id session_date  session_month  gb_used
# 0        1000_13     1000   2018-12-29             12        1
# 1       1000_204     1000   2018-12-31             12        0
# 2       1000_379     1000   2018-12-28             12        1
# 3       1000_413     1000   2018-12-26             12        1
# 4       1000_442     1000   2018-12-27             12        1
# ...          ...      ...          ...            ...      ...
# 104820  1499_215     1499   2018-10-20             10        1
# 104821  1499_216     1499   2018-12-30             12        1
# 104822  1499_217     1499   2018-09-22              9        1
# 104823  1499_218     1499   2018-12-07             12        0
# 104824  1499_219     1499   2018-12-24             12        1
#
# [104825 rows x 5 columns]

# %% [markdown]
# # Estudiar las condiciones de las tarifas

# %%
# Imprime las condiciones de la tarifa y asegúrate de que te quedan claras
plans
# Out:
#    messages_included  gb_per_month_included  minutes_included  \
# 0                 50                   15.0               500
# 1               1000                   30.0              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %% [markdown]
# ## Agregar datos por usuario

# %%
# Calcula el número de llamadas hechas por cada usuario al mes. Guarda el resultado.
calls_per_month = calls.groupby(['user_id', 'call_month'])['id'].count().reset_index()
calls_per_month.columns = ['user_id', 'month', 'calls']
calls_per_month
# Out:
#       user_id  month  calls
# 0        1000     12     16
# 1        1001      8     22
# 2        1001      9     38
# 3        1001     10     47
# 4        1001     11     49
# ...       ...    ...    ...
# 2251     1498     12     32
# 2252     1499      9     35
# 2253     1499     10     41
# 2254     1499     11     39
# 2255     1499     12     56
#
# [2256 rows x 3 columns]

# %%
# Graficar de barras de llamadas por mes
plt.figure(figsize=(15, 5))
plt.title('Número de llamadas por mes')
plt.xlabel('Mes')
plt.ylabel('Número de llamadas')
calls_per_month_sorted = calls_per_month.sort_values('month')
plt.bar(calls_per_month_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), calls_per_month_sorted['calls'])
plt.show()

# %%
# Calcula la cantidad de minutos usados por cada usuario al mes. Guarda el resultado.
minutes_per_month = calls.groupby(['user_id', 'call_month'])['duration_min'].sum().reset_index()
minutes_per_month.columns = ['user_id', 'month', 'minutes']
minutes_per_month
# Out:
#       user_id  month  minutes
# 0        1000     12      124
# 1        1001      8      182
# 2        1001      9      315
# 3        1001     10      393
# 4        1001     11      426
# ...       ...    ...      ...
# 2251     1498     12      339
# 2252     1499      9      346
# 2253     1499     10      385
# 2254     1499     11      308
# 2255     1499     12      496
#
# [2256 rows x 3 columns]

# %%
# Graficar de barras de minutos por mes
plt.figure(figsize=(15, 5))
plt.title('Minutos usados por mes')
plt.xlabel('Mes')
plt.ylabel('Minutos usados')
minutes_per_month_sorted = minutes_per_month.sort_values('month')
plt.bar(minutes_per_month_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), minutes_per_month_sorted['minutes'])
plt.show()

# %%
# Calcula el número de mensajes enviados por cada usuario al mes. Guarda el resultado.
messages_per_month = messages.groupby(['user_id', 'message_month'])['id'].count().reset_index()
messages_per_month.columns = ['user_id', 'month', 'messages']
messages_per_month
# Out:
#       user_id  month  messages
# 0        1000     12        11
# 1        1001      8        30
# 2        1001      9        44
# 3        1001     10        53
# 4        1001     11        36
# ...       ...    ...       ...
# 1801     1496      9        21
# 1802     1496     10        18
# 1803     1496     11        13
# 1804     1496     12        11
# 1805     1497     12        50
#
# [1806 rows x 3 columns]

# %%
# Graficar de barras de mensajes por mes
plt.figure(figsize=(15, 5))
plt.title('Número de mensajes por mes')
plt.xlabel('Mes')
plt.ylabel('Número de mensajes')
messages_per_month_sorted = messages_per_month.sort_values('month')
plt.bar(messages_per_month_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), messages_per_month_sorted['messages'])
plt.show()

# %%
# Calcula el volumen del tráfico de Internet usado por cada usuario al mes. Guarda el resultado.
internet_per_month = internet.groupby(['user_id', 'session_month'])['gb_used'].sum().reset_index()
internet_per_month.columns = ['user_id', 'month', 'gb_used']
internet_per_month
# Out:
#       user_id  month  gb_used
# 0        1000     12        4
# 1        1001      8       21
# 2        1001      9       41
# 3        1001     10       50
# 4        1001     11       49
# ...       ...    ...      ...
# 2272     1498     12       56
# 2273     1499      9       37
# 2274     1499     10       52
# 2275     1499     11       43
# 2276     1499     12       58
#
# [2277 rows x 3 columns]

# %%
# Graficar de barras de tráfico de internet por mes
plt.figure(figsize=(15, 5))
plt.title('Tráfico de internet por mes')
plt.xlabel('Mes')
plt.ylabel('Tráfico de internet (GB)')
internet_per_month_sorted = internet_per_month.sort_values('month')
plt.bar(internet_per_month_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), internet_per_month_sorted['gb_used'])
plt.show()

# %%
# Fusiona los datos de llamadas, minutos, mensajes e Internet con base en user_id y month
df = calls_per_month.merge(minutes_per_month, on=['user_id', 'month'], how='outer')
df = df.merge(messages_per_month, on=['user_id', 'month'], how='outer')
df = df.merge(internet_per_month, on=['user_id', 'month'], how='outer')
df = df.fillna(0)
# Converttir columnas a enteros
df['calls'] = df['calls'].astype(int)
df['minutes'] = df['minutes'].astype(int)
df['messages'] = df['messages'].astype(int)
df['gb_used'] = df['gb_used'].astype(int)
df
# Out:
#       user_id  month  calls  minutes  messages  gb_used
# 0        1000     12     16      124        11        4
# 1        1001      8     22      182        30       21
# 2        1001      9     38      315        44       41
# 3        1001     10     47      393        53       50
# 4        1001     11     49      426        36       49
# ...       ...    ...    ...      ...       ...      ...
# 2288     1498     12     32      339         0       56
# 2289     1499      9     35      346         0       37
# 2290     1499     10     41      385         0       52
# 2291     1499     11     39      308         0       43
# 2292     1499     12     56      496         0       58
#
# [2293 rows x 6 columns]

# %%
# Graficar de barras de llamadas, minutos, mensajes e internet por mes con seaborn en una sola figura
plt.figure(figsize=(15, 5))
plt.title('Llamadas, minutos, mensajes e internet por mes')
plt.xlabel('Mes')
plt.ylabel('Cantidad')
df_sorted = df.sort_values('month')
sns.barplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['calls'], color='blue', label='Llamadas', alpha=0.7)
sns.barplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['minutes'], color='green', label='Minutos', alpha=0.7)
sns.barplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['messages'], color='red', label='Mensajes', alpha=0.7)
sns.barplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['gb_used'], color='purple', label='Internet', alpha=0.7)
plt.legend()
plt.show()

# %%
# Añade la información de la tarifa 
df = df.merge(users, on='user_id', how='left')
df = df.merge(plans, left_on='plan', right_on='plan_name', how='left')
df = df.drop(['plan_name'], axis=1)
df.head()
# Out:
#    user_id  month  calls  minutes  messages  gb_used         full_name  age  \
# 0     1000     12     16      124        11        4    Anamaria Bauer   45
# 1     1001      8     22      182        30       21  Mickey Wilkerson   28
# 2     1001      9     38      315        44       41  Mickey Wilkerson   28
# 3     1001     10     47      393        53       50  Mickey Wilkerson   28
# 4     1001     11     49      426        36       49  Mickey Wilkerson   28
#
#                                     city   reg_date churn_date      plan  \
# 0  Atlanta-Sandy Springs-Roswell, GA MSA 2018-12-24 2018-12-31  ultimate
# 1        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 2        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 3        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 4        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
#
#    messages_included  gb_per_month_included  minutes_included  \
# ...

# %%
# Calcula el ingreso mensual para cada usuario
def monthly_revenue(row):
    revenue = row['usd_monthly_pay']
    if row['minutes'] > row['minutes_included']:
        revenue += (row['minutes'] - row['minutes_included']) * row['usd_per_minute']
    if row['messages'] > row['messages_included']:
        revenue += (row['messages'] - row['messages_included']) * row['usd_per_message']
    if row['gb_used'] > row['gb_per_month_included']:
        revenue += (row['gb_used'] - row['gb_per_month_included']) * row['usd_per_gb']
    return revenue

df['revenue'] = df.apply(monthly_revenue, axis=1)
df.head()
# Out:
#    user_id  month  calls  minutes  messages  gb_used         full_name  age  \
# 0     1000     12     16      124        11        4    Anamaria Bauer   45
# 1     1001      8     22      182        30       21  Mickey Wilkerson   28
# 2     1001      9     38      315        44       41  Mickey Wilkerson   28
# 3     1001     10     47      393        53       50  Mickey Wilkerson   28
# 4     1001     11     49      426        36       49  Mickey Wilkerson   28
#
#                                     city   reg_date churn_date      plan  \
# 0  Atlanta-Sandy Springs-Roswell, GA MSA 2018-12-24 2018-12-31  ultimate
# 1        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 2        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 3        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
# 4        Seattle-Tacoma-Bellevue, WA MSA 2018-08-13 2018-12-31      surf
#
#    messages_included  gb_per_month_included  minutes_included  \
# ...

# %% [markdown]
# # Estudia el comportamiento de usuario

# %% [markdown]
# ## Llamadas

# %%
# Compara la duración promedio de llamadas por cada plan y por cada mes. Traza un gráfico de barras para visualizarla
plt.figure(figsize=(15, 5))
plt.title('Duración promedio de llamadas por plan y mes')
plt.xlabel('Mes')
plt.ylabel('Duración promedio de llamadas')
df['avg_duration'] = df['minutes'] / df['calls']
df_sorted = df.sort_values('month')
sns.barplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['avg_duration'], hue=df_sorted['plan'])
plt.legend(title='Plan')
plt.show()

# %%
# Compara el número de minutos mensuales que necesitan los usuarios de cada plan. Traza un histograma.  
plt.figure(figsize=(15, 5))
plt.title('Número de minutos mensuales por plan')
plt.xlabel('Minutos')
plt.ylabel('Frecuencia')
sns.histplot(df[df['plan'] == 'surf']['minutes'], color='blue', label='Surf', kde=True)
sns.histplot(df[df['plan'] == 'ultimate']['minutes'], color='green', label='Ultimate', kde=True)
plt.legend(title='Plan')
plt.show()

# %%
# Calcula la media y la varianza de la duración mensual de llamadas para cada plan
df.groupby('plan')['minutes'].agg(['mean', 'var'])
# Out:
#                 mean           var
# plan
# surf      428.749523  54968.279461
# ultimate  430.450000  57844.464812

# %%
# Traza un diagrama de caja para visualizar la distribución de la duración mensual de llamadas
plt.figure(figsize=(15, 5))
plt.title('Duración mensual de llamadas por mes')
plt.xlabel('Mes')
plt.ylabel('Duración de llamadas')
df_sorted = df.sort_values('month')
sns.boxplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['minutes'])
plt.show()

# %% [markdown]
# ## Mensajes

# %%
# Comprara el número de mensajes que tienden a enviar cada mes los usuarios de cada plan
plt.figure(figsize=(15, 5))
plt.title('Número de mensajes mensuales por plan')
plt.xlabel('Mensajes')
plt.ylabel('Frecuencia')
sns.histplot(df[df['plan'] == 'surf']['messages'], color='blue', label='Surf', kde=True)
sns.histplot(df[df['plan'] == 'ultimate']['messages'], color='green', label='Ultimate', kde=True)
plt.legend(title='Plan')
plt.show()

# %% [markdown]
# ## Internet

# %%
# Comprara el número de datos que tienden a navegar cada mes los usuarios de cada plan
plt.figure(figsize=(15, 5))
plt.title('Tráfico de internet mensual por plan')
plt.xlabel('Tráfico de internet')
plt.ylabel('Frecuencia')
sns.histplot(df[df['plan'] == 'surf']['gb_used'], color='blue', label='Surf', kde=True)
sns.histplot(df[df['plan'] == 'ultimate']['gb_used'], color='green', label='Ultimate', kde=True)
plt.legend(title='Plan')
plt.show()

# %% [markdown]
# # Ingreso

# %%
# Del mismo modo que has estudiado el comportamiento de los usuarios, describe estadísticamente los ingresos de los planes.
df.groupby('plan')['revenue'].agg('sum').reset_index()
# Out:
#        plan    revenue
# 0      surf  443771.18
# 1  ultimate  119973.00

# %%
# GRaficar los ingresos de cada plan por mes
plt.figure(figsize=(15, 5))
plt.title('Ingresos por mes')
plt.xlabel('Mes')
plt.ylabel('Ingresos')
df_sorted = df.sort_values('month')
sns.barplot(x=df_sorted['month'].map({1: 'Enero', 2: 'Febrero', 3: 'Marzo', 4: 'Abril', 5: 'Mayo', 6: 'Junio', 7: 'Julio', 8: 'Agosto', 9: 'Septiembre', 10: 'Octubre', 11: 'Noviembre', 12: 'Diciembre'}), y=df_sorted['revenue'], hue=df_sorted['plan'])
plt.legend(title='Plan')
plt.show()

# %% [markdown]
# # Prueba las hipótesis estadísticas

# %%
# Prueba las hipótesis de que el ingreso promedio de los usuarios de las tarifas Ultimate y Surf difiere.
# Hipótesis nula: el ingreso promedio de los usuarios de las tarifas Ultimate y Surf es igual
# Hipótesis alternativa: el ingreso promedio de los usuarios de las tarifas Ultimate y Surf difiere
alpha = 0.05
results = st.ttest_ind(df[df['plan'] == 'ultimate']['revenue'], df[df['plan'] == 'surf']['revenue'], equal_var=False)
print('p-valor:', results.pvalue)
if results.pvalue < alpha:
    print('Rechazar la hipótesis nula')
else:
    print('No se puede rechazar la hipótesis nula')
# Out:
# p-valor: 2.3248333100718407e-97
# Rechazar la hipótesis nula

# %%
# Prueba la hipótesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones.
# Hipótesis nula: el ingreso promedio de los usuarios del área NY-NJ es igual al de los usuarios de otras regiones
# Hipótesis alternativa: el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones
alpha = 0.05
results = st.ttest_ind(df[df['city'].str.contains('NY-NJ')]['revenue'], df[~df['city'].str.contains('NY-NJ')]['revenue'], equal_var=False)
print('p-valor:', results.pvalue)
if results.pvalue < alpha:
    print('Rechazar la hipótesis nula')
else:
    print('No se puede rechazar la hipótesis nula')
# Out:
# p-valor: 0.004632562058700096
# Rechazar la hipótesis nula

# %% [markdown]
# # Conclusión general

# %% [markdown]
# De acuerdo a todas nuestras graficas realizadas, observamos que el plan `Surf` es el que tiene mas minutos en llamas, mas mensajes, y mas GB usados; por lo que la mayoria de los usaurios sobrepasan la tarifa base de lo que incluye el plan generando asi mas ingresos que el plan `Ultimate`.
#
# Nuetsra primera hipotesis de que el ingreso promedio de los usuarios de las tarifas Ultimate y Surf difiere, debe ser rechazada ya que como lo vimos el plan `Surf` tiene un ingreso significagtivo en comparacion del plan `Ultimate`
#
# En nuestra segunda hipotesis de que el ingreso promedio de los usuarios del área NY-NJ es diferente al de los usuarios de otras regiones, tambien debe ser rechazada ya que el ingreso promedio no es igual.
#
# Como conclusion debemos decirle a nuestro departamento de marketing que puede hacer mas promocion a uestro plan `Surf`.
